# %%
import pandas as pd
from pathlib import Path

path = Path.cwd().parent / 'MRT_303_10.xlsx'
edu = pd.read_excel(path)
edu.head()
# Out:
#    Unnamed: 0             Unnamed: 1  \
# 0         NaN                    NaN
# 1         NaN        Data File Title
# 2         NaN  Data File Description
# 3         NaN                    NaN
# 4         NaN        MRT File Format
#
#                                           Unnamed: 2 Unnamed: 3
# 0                                                NaN        NaN
# 1           Digest Machine Readable Table (MRT) File        NaN
# 2  MRT files are created to increase the usabilit...        NaN
# 3                                                NaN        NaN
# 4                                              Excel        NaN
