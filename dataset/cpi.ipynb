# %%
import pandas as pd
from pathlib import Path

csv_path = Path.cwd().parent / 'FREDcpi.csv'
cpi_data = pd.read_csv(csv_path)
cpi_data.head()
# Out:
#   observation_date  CORESTICKM159SFRBATL
# 0       2003-01-01              2.778159
# 1       2003-02-01              2.695620
# 2       2003-03-01              2.619135
# 3       2003-04-01              2.450573
# 4       2003-05-01              2.338588

# %%
# observation_date is a date string in YYYY-MM-DD format (no time component).
dates = pd.to_datetime(cpi_data['observation_date'], format='%Y-%m-%d')
cpi_data['Month'] = dates.dt.month
cpi_data['Year'] = dates.dt.year
cpi_data = cpi_data.rename(columns={'CORESTICKM159SFRBATL': 'cpi_pct'})
cpi_data.head()
# Out:
#   observation_date  CORESTICKM159SFRBATL  Month  Year
# 0       2003-01-01              2.778159      1  2003
# 1       2003-02-01              2.695620      2  2003
# 2       2003-03-01              2.619135      3  2003
# 3       2003-04-01              2.450573      4  2003
# 4       2003-05-01              2.338588      5  2003

# %%
def get_cpi():
    return cpi_data
